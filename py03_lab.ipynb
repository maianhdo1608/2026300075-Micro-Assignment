# %% [markdown]
# <a href="https://colab.research.google.com/github/maianhdo1608/2026300075-Micro-Assignment/blob/main/py03_lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
age =20
age +=1
print(age)
# Out:
# 21

# %%
student_name = "Do Thi Mai Anh"
print(student_name)
# Out:
# Do Thi Mai Anh

# %%
midterm=95
final=65
quiz=90
print(midterm,final,quiz)
# Out:
# 95 65 90

# %%
text = "hello"
print(text[0])
print(text[1])
print(text[3])
print(text[0:4])
print(text[0:2:4])
print(text[0:5:2])
# Out:
# h
# e
# l
# hell
# h
# hlo

# %%
text = " abcdefj "
text.strip()
# Out:
# 'abcdefj'

# %%
text.upper()
# Out:
# ' ABCDEFJ '

# %%
text = "a,b,c"
text.split()
# Out:
# ['a,b,c']

# %%
text = "i love python"
len(text)
# Out:
# 13

# %%
text.replace("python","mom")
# Out:
# 'i love mom'

# %%
print(text.count(" "))
# Out:
# 2

# %%
name = "Maianh"
print(f"저는   {name}이고 베트남 유학생입나다.")
# Out:
# 저는   Maianh이고 베트남 유학생입나다.
